# %%
import pymongo

# %%
import pandas as pd

# %%
#Connecting to mongodb
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
db = myclient["mongodb"]

# %% [markdown]
# # Uploading users collection

# %%
df = pd.read_csv('users.csv')
df
# Out:
#                   id             user_name                user_location  \
# 0       1.340000e+18            Rachel Roh    La Crescenta-Montrose, CA
# 1       1.340000e+18              eli🇱🇹🇪🇺👌                     Your Bed
# 2       1.340000e+18  Citizen News Channel                        Empty
# 3       1.340000e+18     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 4       1.340000e+18   Dr.Krutika Kuppalli                        Empty
# ...              ...                   ...                          ...
# 178484  1.460000e+18                VaxBLR             Bengaluru, India
# 178485  1.460000e+18                VaxBLR             Bengaluru, India
# 178486  1.460000e+18                VaxBLR             Bengaluru, India
# 178487  1.460000e+18      Gatti Valentino🐾            Southern  Africa
# 178488  1.460000e+18                VaxBLR             Bengaluru, India
#
#                                          user_description     user_created  \
# ...

# %%
df['id'] = [i for i in range(1, 178490)]
df
# Out:
#             id             user_name                user_location  \
# 0            1            Rachel Roh    La Crescenta-Montrose, CA
# 1            2              eli🇱🇹🇪🇺👌                     Your Bed
# 2            3  Citizen News Channel                        Empty
# 3            4     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 4            5   Dr.Krutika Kuppalli                        Empty
# ...        ...                   ...                          ...
# 178484  178485                VaxBLR             Bengaluru, India
# 178485  178486                VaxBLR             Bengaluru, India
# 178486  178487                VaxBLR             Bengaluru, India
# 178487  178488      Gatti Valentino🐾            Southern  Africa
# 178488  178489                VaxBLR             Bengaluru, India
#
#                                          user_description     user_created  \
# 0       Aggregator of Asian American news; scanning di...   4/8/2009 17:52
# ...

# %%
df.rename(columns={'id': '_id'}, inplace=True)

# %%
df.head()
# Out:
#    _id             user_name                user_location  \
# 0    1            Rachel Roh    La Crescenta-Montrose, CA
# 1    2              eli🇱🇹🇪🇺👌                     Your Bed
# 2    3  Citizen News Channel                        Empty
# 3    4     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 4    5   Dr.Krutika Kuppalli                        Empty
#
#                                     user_description     user_created  \
# 0  Aggregator of Asian American news; scanning di...   4/8/2009 17:52
# 1                                     heil, hydra 🖐☺  6/25/2020 23:30
# 2  Citizen News Channel bringing you an alternati...  4/23/2020 17:58
# 3  End North Stream 2 now - the pipeline of corru...  6/10/2013 17:49
# 4  ID, Global Health, VHF, Pandemic Prep, Emergin...   3/25/2019 4:14
#
#    user_followers  user_friends  user_favourites  user_verified
# 0             405          1692             3247          False
# 1              10            88              155          False
# ...

# %%
collectionUser = db["users"]

# %%
data_dict = df.to_dict(orient= 'records')

# %%
collectionUser.insert_many(data_dict)

# %% [markdown]
# # Uploading tweets collection

# %%
df2 = pd.read_csv('tweets.csv')
df2.head()
# Out:
#              id              date  \
# 0  1.340000e+18   12/20/2020 6:06
# 1  1.340000e+18  12/12/2020 20:33
# 2  1.340000e+18  12/12/2020 20:17
# 3  1.340000e+18  12/12/2020 20:06
# 4  1.340000e+18  12/12/2020 20:04
#
#                                                 text  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 2  Explain to me again why we need a vaccine @Bor...
# 3  it is a bit sad to claim the fame for success ...
# 4  There have not been many bright days in 2020 b...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 2     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# 3                                    ['vaccination']      Twitter Web App
# ...

# %%
df2['id'] = [i for i in range(1, 178490)]
df2
# Out:
#             id              date  \
# 0            1   12/20/2020 6:06
# 1            2  12/12/2020 20:33
# 2            3  12/12/2020 20:17
# 3            4  12/12/2020 20:06
# 4            5  12/12/2020 20:04
# ...        ...               ...
# 178484  178485   11/15/2021 9:00
# 178485  178486   11/15/2021 8:30
# 178486  178487   11/15/2021 8:30
# 178487  178488   11/15/2021 8:03
# 178488  178489   11/15/2021 8:00
#
#                                                      text  \
# 0       Same folks said daikon paste could treat a cyt...
# 1       #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 2       Explain to me again why we need a vaccine @Bor...
# 3       it is a bit sad to claim the fame for success ...
# 4       There have not been many bright days in 2020 b...
# ...                                                   ...
# 178484  45+ #URBAN #Bengaluru #CovidVaccine Availabili...
# 178485  18-44 #BBMP #Bengaluru #CovidVaccine Availabil...
# ...

# %%
df2.rename(columns={'id': 'uId'}, inplace=True)
df2.head()
# Out:
#    uId              date                                               text  \
# 0    1   12/20/2020 6:06  Same folks said daikon paste could treat a cyt...
# 1    2  12/12/2020 20:33  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 2    3  12/12/2020 20:17  Explain to me again why we need a vaccine @Bor...
# 3    4  12/12/2020 20:06  it is a bit sad to claim the fame for success ...
# 4    5  12/12/2020 20:04  There have not been many bright days in 2020 b...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 2     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# 3                                    ['vaccination']      Twitter Web App
# 4                    ['BidenHarris', 'Election2020']   Twitter for iPhone
#
#    retweets  favorites  is_retweet Sentiment
# ...

# %%
collectionTweets = db["tweets"]

# %%
data_dict = df2.to_dict(orient= 'records')

# %%
 collectionTweets.insert_many(data_dict)
